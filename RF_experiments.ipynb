# %%
from biasvariancetradeoff.random_forest import ExperimentRunner, RandomForestWrapper
from biasvariancetradeoff.data import get_test, get_train

# %%
# Get Data
test_data = get_test()
train_data = get_train()

# %%
# Initialize Parameters
paper_params = [{"max_leaf_nodes":50, "num_estimators":1},
                {"max_leaf_nodes":60, "num_estimators":1},
                {"max_leaf_nodes":70, "num_estimators":1},
                {"max_leaf_nodes":80, "num_estimators":1},
                {"max_leaf_nodes":90, "num_estimators":1},
                {"max_leaf_nodes":100, "num_estimators":1},
                {"max_leaf_nodes":120, "num_estimators":1},
                {"max_leaf_nodes":140, "num_estimators":1},
               {"max_leaf_nodes":160, "num_estimators":1},
               {"max_leaf_nodes":180, "num_estimators":1},
               {"max_leaf_nodes":200, "num_estimators":1},
               {"max_leaf_nodes":300, "num_estimators":1},
               {"max_leaf_nodes":400, "num_estimators":1},
               {"max_leaf_nodes":500, "num_estimators":1},
                {"max_leaf_nodes":600, "num_estimators":1},
                {"max_leaf_nodes":700, "num_estimators":1},
               {"max_leaf_nodes":800, "num_estimators":1},
                {"max_leaf_nodes":900, "num_estimators":1},
               {"max_leaf_nodes":1000, "num_estimators":1},
               {"max_leaf_nodes":2000, "num_estimators":1},
               {"max_leaf_nodes":2000, "num_estimators":2},
               {"max_leaf_nodes":2000, "num_estimators":4},
               {"max_leaf_nodes":2000, "num_estimators":8},
                {"max_leaf_nodes":2000, "num_estimators":10},
                {"max_leaf_nodes":2000, "num_estimators":20},]
# Instantiate Experiment Runner
runner = ExperimentRunner(RandomForestWrapper, paper_params, train_data, test_data)

# %%
# Run Experiments
runner.run()
# Out:
# Function: train, Time Delta: 0.2760498523712158
# Function: predict, Time Delta: 0.058390140533447266
# Function: predict, Time Delta: 0.011695146560668945
# Function: get_loss, Time Delta: 0.001417398452758789
# Function: get_loss, Time Delta: 0.02299213409423828
# Function: get_loss, Time Delta: 0.0005028247833251953
# Function: get_loss, Time Delta: 0.0038280487060546875
# Function: train, Time Delta: 0.2979261875152588
# Function: predict, Time Delta: 0.0562591552734375
# Function: predict, Time Delta: 0.009241104125976562
# Function: get_loss, Time Delta: 0.001421213150024414
# Function: get_loss, Time Delta: 0.024477005004882812
# Function: get_loss, Time Delta: 0.0006191730499267578
# Function: get_loss, Time Delta: 0.00426793098449707
# Function: train, Time Delta: 0.2868180274963379
# Function: predict, Time Delta: 0.05825209617614746
# Function: predict, Time Delta: 0.00917506217956543
# Function: get_loss, Time Delta: 0.0014820098876953125
# Function: get_loss, Time Delta: 0.023702144622802734
# Function: get_loss, Time Delta: 0.0005021095275878906
# Function: get_loss, Time Delta: 0.003773212432861328
# Function: train, Time Delta: 0.29778623580932617
# Function: predict, Time Delta: 0.05813097953796387
# Function: predict, Time Delta: 0.01472926139831543
# Function: get_loss, Time Delta: 0.0014469623565673828
# Function: get_loss, Time Delta: 0.024010181427001953
# Function: get_loss, Time Delta: 0.0004222393035888672
# Function: get_loss, Time Delta: 0.003985881805419922
# Function: train, Time Delta: 0.2862379550933838
# Function: predict, Time Delta: 0.05632781982421875
# Function: predict, Time Delta: 0.00927281379699707
# Function: get_loss, Time Delta: 0.0014500617980957031
# Function: get_loss, Time Delta: 0.023675918579101562
# Function: get_loss, Time Delta: 0.001241922378540039
# Function: get_loss, Time Delta: 0.003753185272216797
# Function: train, Time Delta: 0.28324413299560547
# Function: predict, Time Delta: 0.06048321723937988
# Function: predict, Time Delta: 0.008543252944946289
# Function: get_loss, Time Delta: 0.0013518333435058594
# Function: get_loss, Time Delta: 0.023995161056518555
# Function: get_loss, Time Delta: 0.0004279613494873047
# Function: get_loss, Time Delta: 0.003942966461181641
# Function: train, Time Delta: 0.29067111015319824
# Function: predict, Time Delta: 0.058390140533447266
# Function: predict, Time Delta: 0.014194965362548828
# Function: get_loss, Time Delta: 0.0014488697052001953
# Function: get_loss, Time Delta: 0.02297186851501465
# Function: get_loss, Time Delta: 0.0003859996795654297
# Function: get_loss, Time Delta: 0.0037970542907714844
# Function: train, Time Delta: 0.3231468200683594
# Function: predict, Time Delta: 0.055908918380737305
# Function: predict, Time Delta: 0.008954048156738281
# Function: get_loss, Time Delta: 0.0013399124145507812
# Function: get_loss, Time Delta: 0.023132801055908203
# Function: get_loss, Time Delta: 0.0004508495330810547
# Function: get_loss, Time Delta: 0.0038280487060546875
# Function: train, Time Delta: 0.31236886978149414
# Function: predict, Time Delta: 0.055516958236694336
# Function: predict, Time Delta: 0.008916854858398438
# Function: get_loss, Time Delta: 0.0014150142669677734
# Function: get_loss, Time Delta: 0.022569894790649414
# Function: get_loss, Time Delta: 0.00032806396484375
# Function: get_loss, Time Delta: 0.003875255584716797
# Function: train, Time Delta: 0.3229200839996338
# Function: predict, Time Delta: 0.055763959884643555
# Function: predict, Time Delta: 0.008949041366577148
# Function: get_loss, Time Delta: 0.0013964176177978516
# Function: get_loss, Time Delta: 0.022980213165283203
# Function: get_loss, Time Delta: 0.0004961490631103516
# Function: get_loss, Time Delta: 0.0038652420043945312
# Function: train, Time Delta: 0.32229089736938477
# Function: predict, Time Delta: 0.06330513954162598
# Function: predict, Time Delta: 0.008851051330566406
# Function: get_loss, Time Delta: 0.0014150142669677734
# Function: get_loss, Time Delta: 0.023602962493896484
# Function: get_loss, Time Delta: 0.0003879070281982422
# Function: get_loss, Time Delta: 0.0038919448852539062
# Function: train, Time Delta: 0.3450479507446289
# Function: predict, Time Delta: 0.056420087814331055
# Function: predict, Time Delta: 0.011595964431762695
# Function: get_loss, Time Delta: 0.0014977455139160156
# Function: get_loss, Time Delta: 0.023492097854614258
# Function: get_loss, Time Delta: 0.0007150173187255859
# Function: get_loss, Time Delta: 0.003787994384765625
# Function: train, Time Delta: 0.3499269485473633
# Function: predict, Time Delta: 0.05667686462402344
# Function: predict, Time Delta: 0.008970975875854492
# Function: get_loss, Time Delta: 0.0013911724090576172
# Function: get_loss, Time Delta: 0.023682832717895508
# Function: get_loss, Time Delta: 0.0007662773132324219
# Function: get_loss, Time Delta: 0.003921031951904297
# Function: train, Time Delta: 0.3834421634674072
# Function: predict, Time Delta: 0.05917811393737793
# Function: predict, Time Delta: 0.00896906852722168
# Function: get_loss, Time Delta: 0.0013680458068847656
# Function: get_loss, Time Delta: 0.023343801498413086
# Function: get_loss, Time Delta: 0.0007691383361816406
# Function: get_loss, Time Delta: 0.003846883773803711
# Function: train, Time Delta: 0.3848910331726074
# Function: predict, Time Delta: 0.05970501899719238
# Function: predict, Time Delta: 0.011069297790527344
# Function: get_loss, Time Delta: 0.0014200210571289062
# Function: get_loss, Time Delta: 0.02323603630065918
# Function: get_loss, Time Delta: 0.0007717609405517578
# Function: get_loss, Time Delta: 0.003907918930053711
# Function: train, Time Delta: 0.4010629653930664
# Function: predict, Time Delta: 0.06224417686462402
# Function: predict, Time Delta: 0.009308815002441406
# Function: get_loss, Time Delta: 0.0015568733215332031
# Function: get_loss, Time Delta: 0.022350788116455078
# Function: get_loss, Time Delta: 0.002119302749633789
# Function: get_loss, Time Delta: 0.003912925720214844
# Function: train, Time Delta: 0.4153721332550049
# Function: predict, Time Delta: 0.06261301040649414
# Function: predict, Time Delta: 0.009250164031982422
# Function: get_loss, Time Delta: 0.0013790130615234375
# Function: get_loss, Time Delta: 0.022328615188598633
# Function: get_loss, Time Delta: 0.000457763671875
# Function: get_loss, Time Delta: 0.0037140846252441406
# Function: train, Time Delta: 0.39861416816711426
# Function: predict, Time Delta: 0.058145999908447266
# Function: predict, Time Delta: 0.015201091766357422
# Function: get_loss, Time Delta: 0.0014142990112304688
# Function: get_loss, Time Delta: 0.0234982967376709
# Function: get_loss, Time Delta: 0.0019249916076660156
# Function: get_loss, Time Delta: 0.0038919448852539062
# Function: train, Time Delta: 0.4164459705352783
# Function: predict, Time Delta: 0.05774831771850586
# Function: predict, Time Delta: 0.011547088623046875
# Function: get_loss, Time Delta: 0.0014128684997558594
# Function: get_loss, Time Delta: 0.023538827896118164
# Function: get_loss, Time Delta: 0.0005090236663818359
# Function: get_loss, Time Delta: 0.003962993621826172
# Function: train, Time Delta: 0.44843006134033203
# Function: predict, Time Delta: 0.05942106246948242
# Function: predict, Time Delta: 0.009696006774902344
# Function: get_loss, Time Delta: 0.0014259815216064453
# Function: get_loss, Time Delta: 0.023366928100585938
# Function: get_loss, Time Delta: 0.0013020038604736328
# Function: get_loss, Time Delta: 0.003885030746459961
# Function: train, Time Delta: 0.8714869022369385
# Function: predict, Time Delta: 0.08581709861755371
# Function: predict, Time Delta: 0.018573284149169922
# Function: get_loss, Time Delta: 0.0014379024505615234
# Function: get_loss, Time Delta: 0.023417949676513672
# Function: get_loss, Time Delta: 0.0003829002380371094
# Function: get_loss, Time Delta: 0.003919124603271484
# Function: train, Time Delta: 1.640906810760498
# Function: predict, Time Delta: 0.14778494834899902
# Function: predict, Time Delta: 0.01961493492126465
# Function: get_loss, Time Delta: 0.0013680458068847656
# Function: get_loss, Time Delta: 0.023917675018310547
# Function: get_loss, Time Delta: 0.0003650188446044922
# Function: get_loss, Time Delta: 0.004040241241455078
# Function: train, Time Delta: 3.2453861236572266
# Function: predict, Time Delta: 0.235306978225708
# Function: predict, Time Delta: 0.03441572189331055
# Function: get_loss, Time Delta: 0.0014629364013671875
# Function: get_loss, Time Delta: 0.0238189697265625
# Function: get_loss, Time Delta: 0.0003578662872314453
# Function: get_loss, Time Delta: 0.003969907760620117
# Function: train, Time Delta: 4.038236856460571
# Function: predict, Time Delta: 0.2881448268890381
# Function: predict, Time Delta: 0.03991389274597168
# Function: get_loss, Time Delta: 0.001645803451538086
# Function: get_loss, Time Delta: 0.022394895553588867
# Function: get_loss, Time Delta: 0.0003371238708496094
# Function: get_loss, Time Delta: 0.003751993179321289
# Function: train, Time Delta: 8.1057870388031
# Function: predict, Time Delta: 0.5240809917449951
# Function: predict, Time Delta: 0.07329201698303223
# Function: get_loss, Time Delta: 0.0015339851379394531
# Function: get_loss, Time Delta: 0.02437877655029297
# Function: get_loss, Time Delta: 0.0005970001220703125
# Function: get_loss, Time Delta: 0.0040700435638427734

# %%
# Plot Losses
runner.plot_square_loss()
# Out:
# /Users/giulio/PycharmProjects/MathStatsFinal/biasvariancetradeoff/random_forest.py:129: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(self.param_axis_labels)

# %%
runner.plot_zero_one_loss()
# Out:
# /Users/giulio/PycharmProjects/MathStatsFinal/biasvariancetradeoff/random_forest.py:116: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(self.param_axis_labels)

# %%
runner.results_to_csv()
